# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
market=pd.read_csv("C:/Users/karthika/Downloads/monthwise.csv")

# %%
data=pd.DataFrame(x)

# %%
data
# Out:
#            market     month  year  quantity  priceMin  priceMax  priceMod  \
# 0      ABOHAR(PB)   January  2005      2350       404       493       446
# 1      ABOHAR(PB)   January  2006       900       487       638       563
# 2      ABOHAR(PB)   January  2010       790      1283      1592      1460
# 3      ABOHAR(PB)   January  2011       245      3067      3750      3433
# 4      ABOHAR(PB)   January  2012      1035       523       686       605
# ...           ...       ...   ...       ...       ...       ...       ...
# 10222   YEOLA(MS)  December  2011    131326       282       612       526
# 10223   YEOLA(MS)  December  2012    207066       485      1327      1136
# 10224   YEOLA(MS)  December  2013    215883       472      1427      1177
# 10225   YEOLA(MS)  December  2014    201077       446      1654      1456
# 10226   YEOLA(MS)  December  2015    223315       609      1446      1126
#
#       state    city    date
# 0        PB  ABOHAR  Jan-05
# ...

# %%
data.shape
# Out:
# (10227, 10)

# %%
data.describe()
# Out:
#                year      quantity      priceMin      priceMax      priceMod
# count  10227.000000  1.022700e+04  10227.000000  10227.000000  10227.000000
# mean    2009.022294  7.660488e+04    646.944363   1212.760731    984.284345
# std        4.372841  1.244087e+05    673.121850    979.658874    818.471498
# min     1996.000000  2.000000e+01     16.000000    145.000000     80.000000
# 25%     2006.000000  8.898000e+03    209.000000    557.000000    448.000000
# 50%     2009.000000  2.746000e+04    440.000000    923.000000    747.000000
# 75%     2013.000000  8.835650e+04    828.000000   1527.000000   1248.000000
# max     2016.000000  1.639032e+06   6000.000000   8192.000000   6400.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10227 entries, 0 to 10226
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   market    10227 non-null  object
#  1   month     10227 non-null  object
#  2   year      10227 non-null  int64
#  3   quantity  10227 non-null  int64
#  4   priceMin  10227 non-null  int64
#  5   priceMax  10227 non-null  int64
#  6   priceMod  10227 non-null  int64
#  7   state     10227 non-null  object
#  8   city      10227 non-null  object
#  9   date      10227 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 799.1+ KB

# %%
data.isnull().sum()
# Out:
# market      0
# month       0
# year        0
# quantity    0
# priceMin    0
# priceMax    0
# priceMod    0
# state       0
# city        0
# date        0
# dtype: int64

# %%
data.dtypes
# Out:
# market      object
# month       object
# year         int64
# quantity     int64
# priceMin     int64
# priceMax     int64
# priceMod     int64
# state       object
# city        object
# date        object
# dtype: object

# %% [markdown]
# <b>Mumbai Market</b>

# %%
Month_wise=pd.DataFrame(Onions[Onions.city=="MUMBAI"]["priceMod"])
Month_wise
# Out:
#         priceMod
# date
# Apr-04       397
# Apr-05       328
# Apr-06       290
# Apr-07       531
# Apr-08       418
# ...          ...
# Sep-11      1286
# Sep-12       707
# Sep-13      4550
# Sep-14      1552
# Sep-15      4714
#
# [146 rows x 1 columns]

# %%
Onion = data.loc[df.city == "MUMBAI"].copy()
Onion
# Out:
#       market     month  year  quantity  priceMin  priceMax  priceMod state  \
# 6654  MUMBAI   January  2004    267100       719       971       849    MS
# 6655  MUMBAI   January  2005    275845       261       513       387    MS
# 6656  MUMBAI   January  2006    228000       315       488       402    MS
# 6657  MUMBAI   January  2007    205200       866      1136       997    MS
# 6658  MUMBAI   January  2008    267550       348       550       448    MS
# ...      ...       ...   ...       ...       ...       ...       ...   ...
# 6795  MUMBAI  December  2011    290350       519       994       749    MS
# 6796  MUMBAI  December  2012    218500      1048      1609      1330    MS
# 6797  MUMBAI  December  2013    226385      1298      1976      1639    MS
# 6798  MUMBAI  December  2014    294150      1433      2178      1802    MS
# 6799  MUMBAI  December  2015    302409      1027      1877      1542    MS
#
#         city    date
# 6654  MUMBAI  Jan-04
# 6655  MUMBAI  Jan-05
# ...

# %%
market.plot(figsize=(15,4))
plt.show()

# %%
Onion1 = Onion.drop(["market","month","year","quantity","priceMin","priceMax","state"], axis=1)
Onion1
# Out:
#       priceMod    city    date
# 6654       849  MUMBAI  Jan-04
# 6655       387  MUMBAI  Jan-05
# 6656       402  MUMBAI  Jan-06
# 6657       997  MUMBAI  Jan-07
# 6658       448  MUMBAI  Jan-08
# ...        ...     ...     ...
# 6795       749  MUMBAI  Dec-11
# 6796      1330  MUMBAI  Dec-12
# 6797      1639  MUMBAI  Dec-13
# 6798      1802  MUMBAI  Dec-14
# 6799      1542  MUMBAI  Dec-15
#
# [146 rows x 3 columns]

# %%
Onion1["log_priceMod"] = np.log(Onion1.priceMod)

# %%
Onion_mean = Onion1.log_priceMod.mean()
Onion1["mean_price"] = np.exp(Onion_mean)
Onion1.head()
# Out:
#       priceMod    city    date  log_priceMod  mean_price
# 6654       849  MUMBAI  Jan-04      6.744059  889.100239
# 6655       387  MUMBAI  Jan-05      5.958425  889.100239
# 6656       402  MUMBAI  Jan-06      5.996452  889.100239
# 6657       997  MUMBAI  Jan-07      6.904751  889.100239
# 6658       448  MUMBAI  Jan-08      6.104793  889.100239

# %%
Onion1.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
x="date"

# %%
y=["priceMod", "mean_price"]

# %% [markdown]
# <b>RMSE</b>

# %%
def RMSE(actual, predicted):
    mse = (actual - predicted)**2
    rmse = np.sqrt(mse.sum()/mse.count())
    return rmse

# %%
mean_modelRMSE = RMSE(Onion1.priceMod, Onion1.mean_price)
mean_modelRMSE
# Out:
# 908.4772843986449

# %% [markdown]
# <b>ACF and PACF plots</b>

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plot_acf(df['priceMod'].tolist(), lags=20)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing as HWES
